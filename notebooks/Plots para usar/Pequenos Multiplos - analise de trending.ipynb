# %%
import os

import plotly

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Criando diretório para salvarmos as visualizações
os.makedirs('pequenos_multiplos', exist_ok=True)

# %% [markdown]
# ## Lendo os dados

# %%
us_data = pd.read_csv('USdata.csv', parse_dates=['publish_time', 'trending_date'])
us_data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  0mlNzVSJrT0    2017-11-14
# 2  STI2fI7sKMo    2017-11-14
# 3  KODzih-pYlU    2017-11-14
# 4  8mhTWqWlQzU    2017-11-14
#
#                                                title       channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                               Me-O Cats Commercial             Nobrand
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4      Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
#
#    category_id publish_time  \
# 0           22   2017-11-13
# 1           22   2017-04-21
# 2           22   2017-11-11
# 3           22   2017-11-11
# 4           22   2017-11-11
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1                          cute|"cats"|"thai"|"eggs"    98966    2486
# 2  shawn johnson|"andrew east"|"shawn east"|"shaw...   321053    4451
# 3  itsgrace|"funny"|"comedy"|"vlog"|"grace"|"helb...   197062    7250
# 4  wearing online dollar store makeup for a week|...  2744430  115426
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1       184            532  https://i.ytimg.com/vi/0mlNzVSJrT0/default.jpg
# 2      1772            895  https://i.ytimg.com/vi/STI2fI7sKMo/default.jpg
# 3       217            456  https://i.ytimg.com/vi/KODzih-pYlU/default.jpg
# 4      1110           6541  https://i.ytimg.com/vi/8mhTWqWlQzU/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description   category_name
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...  People & Blogs
# 1  Kittens come out of the eggs in a Thai commerc...  People & Blogs
# 2  Subscribe for weekly videos ▶ http://bit.ly/sj...  People & Blogs
# 3  Molly is an god damn amazing human and she cha...  People & Blogs
# 4  I found this online dollar store called ShopMi...  People & Blogs

# %% [markdown]
# ## Definindo espectro de cores

# %%
# Gerando um array de cores do arco-íris fixando a saturação e brilho da
# representação HSL da cor e caminhando pela matiz.
category_colors = [f'hsl({h},50%,50%)' for h in np.linspace(0, 360, 30)]

# %% [markdown]
# ## Construíndo a visualização

# %% [markdown]
# ### 1) Número de vídeos que entraram em trending mais de uma vez

# %%
trend_count = us_data.groupby(['title', 'category_name']).size()
trend_count = trend_count.to_frame('trend_count')
trend_count = trend_count.reset_index()

trend_count = trend_count[trend_count['trend_count'] > 1]
trend_count.head()
# Out:
#                                                title         category_name  \
# 1         #23 Feed The Homeless | One List, One Life        People & Blogs
# 2                          #57: AM and SSB explained  Science & Technology
# 4  #DisneyParksLIVE: Fantasy In The Sky New Years...         Entertainment
# 5  #DisneyParksLIVE: Super Bowl Celebration | Wal...       Travel & Events
# 6                                         #EDGYTOKEI  Science & Technology
#
#    trend_count
# 1            6
# 2            4
# 4            4
# 5            4
# 6            2

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(12,10))

categories = trend_count['category_name'].unique().reshape((4,4))
for i in range(4):
    for j in range(4):
        category = categories[i][j]
        axs[i,j].set_title(f'{category}')
        axs[i,j].hist(trend_count[trend_count['category_name'] == category]['trend_count'])

fig.suptitle('Número de vídeos que entraram em trending mais de uma vez', fontsize=18)

# add a big axis, hide frame
fig.add_subplot(111, frameon=False)
fig.tight_layout()

# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel('Quantidade de dias em trend', fontsize=14)
plt.ylabel('Número de vídeos', fontsize=14)
plt.show()

# %%
# Salvando a visualização
fig.savefig('pequenos_multiplos/trend_count.png')

# %% [markdown]
# ### 2) Tempo necessário para o vídeo entrar em trend

# %%
def get_trend_start_time(df):
    return (df['trending_date'].iloc[0] - df['publish_time'].iloc[0]).days

trend_start_time = us_data.groupby(['title', 'publish_time']).apply(get_trend_start_time)
trend_start_time = trend_start_time.to_frame('trend_start_time')
trend_start_time = trend_start_time.sort_values('trend_start_time')

trend_start_time.head()
# Out:
#                                                                  trend_start_time
# title                                              publish_time
# Judge Roy Moore Campaign Statement                 2017-12-14                   0
# Nintendo @ E3 2018: Day 1                          2018-06-13                   0
# Nintendo @ E3 2018: Day 2                          2018-06-14                   0
# Eagles' Home Radio Call of the Last Play of Sup... 2018-02-05                   0
# Zedd, Maren Morris, Grey - The Middle (Presente... 2018-01-29                   0

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(12,10))

ax1.set_title('Histograma padrão', fontsize=14)
ax1.set_ylabel('Contagem de vídeos', fontsize=12)
ax1.set_xlabel('Tempo mínimo', fontsize=12)
ax1.hist(trend_start_time.values)

ax2.set_title('Histograma xlog', fontsize=14)
ax2.set_ylabel('Contagem de vídeos', fontsize=12)
ax2.set_xlabel('Tempo mínimo > 0 (escala log10)', fontsize=12)
ax2.hist(np.log10(trend_start_time[trend_start_time > 0].values))

ax3.set_title('Histograma ylog', fontsize=14)
ax3.set_ylabel('Contagem de vídeos (escala log10)', fontsize=12)
ax3.set_xlabel('Tempo mínimo', fontsize=12)
ax3.hist(trend_start_time, log=True)

ax4.set_title('Histograma log-log)', fontsize=14)
ax4.set_ylabel('Contagem de vídeos (escala log10)', fontsize=12)
ax4.set_xlabel('Tempo mínimo > 0 (escala log10)', fontsize=12)
ax4.hist(np.log10(trend_start_time[trend_start_time > 0].values), log=True)

fig.suptitle('Tempo necessário em dias para o vídeo entrar em trend', fontsize=18)
fig.tight_layout()

# %%
# Salvando a visualização
fig.savefig('pequenos_multiplos/trend_start_time.png')

# %% [markdown]
# ### 3) Maior janela temporal onde um vídeo ficou em trend por categoria

# %%
def biggest_window_trend_time(df):
    max_window = 1
    diff1 = df['trending_date'].diff() == pd.Timedelta('1D')
    
    counter = 0
    for value in diff1:
        counter = counter + 1 if value else 1
        max_window = max(max_window, counter)
        
    return max_window

max_trend_window = us_data.groupby(['title', 'category_name']).apply(biggest_window_trend_time)
max_trend_window = max_trend_window.to_frame('max_trend_window')
max_trend_window = max_trend_window.reset_index()

max_trend_window.head()
# Out:
#                                                title         category_name  \
# 0         #184 Making a PCB using EasyEDA. // Review  Science & Technology
# 1         #23 Feed The Homeless | One List, One Life        People & Blogs
# 2                          #57: AM and SSB explained  Science & Technology
# 3  #AboveTheNoise feat. Serena Williams, Neymar J...                 Music
# 4  #DisneyParksLIVE: Fantasy In The Sky New Years...         Entertainment
#
#    max_trend_window
# 0                 1
# 1                 6
# 2                 4
# 3                 1
# 4                 4

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(12,10))

categories = max_trend_window['category_name'].unique().reshape((4,4))
for i in range(4):
    for j in range(4):
        category = categories[i][j]
        axs[i,j].set_title(f'{category}')
        axs[i,j].hist(max_trend_window[max_trend_window['category_name'] == category]['max_trend_window'])

fig.suptitle('Maior janela de trend para os vídeos de cada categoria', fontsize=18)

# add a big axis, hide frame
fig.add_subplot(111, frameon=False)
fig.tight_layout()

# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel('Janela máxima (em dias)', fontsize=14)
plt.ylabel('Número de vídeos', fontsize=14)
plt.show()

# %%
# Salvando a visualização
fig.savefig('pequenos_multiplos/max_trend_window.png')
